# %%
import oddt
from oddt import docking
# ?docking
# Out:
# Type:        module
# String form: <module 'oddt.docking' from '/home/james/anaconda3/envs/bm3/lib/python3.6/site-packages/oddt/docking/__init__.py'>
# File:        ~/anaconda3/envs/bm3/lib/python3.6/site-packages/oddt/docking/__init__.py
# Docstring:   <no docstring>

# %%
protein = next(oddt.toolkit.readfile('pdb','../data/clean/1jme_clean.pdb'))
#vina = docking.AutodockVina.autodock_vina(protein)
protein

# %%
mol = oddt.toolkit.readstring('smi', 'c1ccccc1')
dir(mol)
# Out:
# ['OBMol',
#  '_OBMol',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_atom_dict',
#  '_charges',
#  '_cinfony',
#  '_clear_cache',
#  '_coords',
#  '_dicts',
#  '_exchange',
#  '_gettitle',
#  '_protein',
#  '_repr_html_',
#  '_repr_png_',
#  '_repr_svg_',
#  '_res_dict',
#  '_ring_dict',
#  '_settitle',
#  '_source',
#  'addh',
#  'atom_dict',
#  'atoms',
#  'bonds',
#  'calccharges',
#  'calcdesc',
#  'calcfp',
#  'canonic_order',
#  'charge',
#  'charges',
#  'clone',
#  'clone_coords',
#  'conformers',
#  'convertdbonds',
#  'coords',
# ...
